# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
data =  pd.read_csv("areaburntbywildfiresbyweek new.csv")
data
# Out:
#                       Entity      Code  Year  area burnt by wildfires in 2024  \
# 0                Afghanistan       AFG     1                              391
# 1                     Africa         0     1                          6036545
# 2      Akrotiri and Dhekelia  OWID_AKD     1                                0
# 3              Aland Islands       ALA     1                                0
# 4                    Albania       ALB     1                                0
# ...                      ...       ...   ...                              ...
# 13411         Western Sahara       ESH    52                                0
# 13412                  World  OWID_WRL    52                                0
# 13413                  Yemen       YEM    52                                0
# 13414                 Zambia       ZMB    52                                0
# 13415               Zimbabwe       ZWE    52                                0
#
# ...

# %%
# Verifică primele rânduri ale datelor
print(data.head())
# Out:
#                   Entity      Code  Year  area burnt by wildfires in 2024  \
# 0            Afghanistan       AFG     1                              391
# 1                 Africa         0     1                          6036545
# 2  Akrotiri and Dhekelia  OWID_AKD     1                                0
# 3          Aland Islands       ALA     1                                0
# 4                Albania       ALB     1                                0
#
#     burnt by wildfires in 2023   burnt by wildfires in 2022  \
# 0                            0                            0
# 1                      6666179                      5144202
# 2                            0                            0
# 3                            0                            0
# 4                            0                            0
#
#     burnt by wildfires in 2021   burnt by wildfires in 2020  \
# 0                         1246                            0
# ...

# %%
import pandas as pd
import numpy as np

def gradient_descent(x, y, learning_rate=0.001, iterations=100):
    m_curr = b_curr = 0  # Inițializare coeficienti
    n = len(x)
    
    for i in range(iterations):
        
        y_predicted = m_curr * x + b_curr
        
        
        cost = (1/n) * sum([val ** 2 for val in (y - y_predicted)])
        
     
        md = -(2/n) * sum(x * (y - y_predicted))
        bd = -(2/n) * sum(y - y_predicted)
        
  
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        
     
        if i % 10 == 0: 
            print(f"m {m_curr}, b {b_curr}, iteration {i}, cost {cost}")
    
    return m_curr, b_curr

def predict_future_fire_area_per_country(data_path, future_years, learning_rate=0.001, iterations=100):
   
    data = pd.read_csv(data_path)
    

    predictions = {}
    
 
    grouped_data = data.groupby('Entity')
    
    for country, group in grouped_data:
        x = group['Year'].values
        y = group['area burnt by wildfires in 2024'].values
        
   
        m, b = gradient_descent(x, y, learning_rate, iterations)
        
    
        future_years_array = np.array(future_years)
        future_area_predictions = m * future_years_array + b
        

        predictions[country] = dict(zip(future_years, future_area_predictions))
    
    return predictions


data_path = 'areaburntbywildfiresbyweek new.csv'  
future_years = [2025, 2026, 2027]  
predictions = predict_future_fire_area_per_country(data_path, future_years)
for country, prediction in predictions.items():
    print(f"\nPrediction for {country}:")
    for year, area in prediction.items():
        print(f"Year {year}: {area:.2f} km²")
# Out:
# m 3.949769230769231, b 0.4786538461538462, iteration 0, cost 222564.09615384616
# m 2.406771818508187, b 4.082545099769047, iteration 10, cost 217197.00437192732
# m 1.9973627202569373, b 7.70116733720914, iteration 20, cost 215696.93308093943
# m 1.8292299578896856, b 11.309104806669259, iteration 30, cost 214383.6250529474
# m 1.7127600463528623, b 14.901023695957576, iteration 40, cost 213090.78454221456
# m 1.607659220848253, b 18.47585717480122, iteration 50, cost 211810.78635718094
# m 1.505363376124469, b 22.033444801600165, iteration 60, cost 210543.17104002953
# m 1.404050800835223, b 25.573818416708452, iteration 70, cost 209287.80380703928
# m 1.303332515782257, b 29.097050400089312, iteration 80, cost 208044.56563662292
# m 1.2031239988472824, b 32.60322142841609, iteration 90, cost 206813.33931007015
# m 174143.4582692308, b 19326.541192307694, iteration 0, cost 400042512833088.9
# m 106637.9718375908, b 160511.95326577395, iteration 10, cost 390152718496151.0
# ...
